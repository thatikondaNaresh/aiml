# %%
Q1:

Data encoding is the process of converting categorical data into numerical data that can be used by machine learning algorithms. It is useful in data science because many algorithms require numerical input, and encoding categorical data allows us to use these algorithms to make predictions and analyze relationships.

Q2:

Nominal encoding is a technique used to encode categorical data by assigning a unique integer value to each category. For example, suppose we have a dataset with a feature "color" that can take on the values "red", "green", and "blue". We can use nominal encoding to assign the values 0, 1, and 2 to these categories, respectively.

Example: Suppose we have a dataset with a feature "gender" that can take on the values "male" and "female". We can use nominal encoding to assign the values 0 and 1 to these categories, respectively.

Q3:

Nominal encoding is preferred over one-hot encoding when the categories have a natural order or hierarchy. For example, suppose we have a dataset with a feature "education level" that can take on the values "high school", "bachelor's degree", and "master's degree". We can use nominal encoding to assign the values 0, 1, and 2 to these categories, respectively, to reflect the increasing level of education.

Example: Suppose we have a dataset with a feature "credit score" that can take on the values "poor", "fair", "good", and "excellent". We can use nominal encoding to assign the values 0, 1, 2, and 3 to these categories, respectively, to reflect the increasing creditworthiness.

Q4:

I would use one-hot encoding to transform the categorical data into a format suitable for machine learning algorithms. One-hot encoding creates a new binary feature for each category, which allows the algorithm to treat each category as a separate feature. This is useful when the categories do not have a natural order or hierarchy.

Q5:

If we use nominal encoding to transform the categorical data, we would create 2 new columns, one for each categorical feature. The number of new columns is equal to the number of categorical features.

Calculation:

Number of new columns = Number of categorical features
= 2

Q6:

I would use one-hot encoding to transform the categorical data into a format suitable for machine learning algorithms. One-hot encoding is useful when the categories do not have a natural order or hierarchy, and it allows the algorithm to treat each category as a separate feature.

Justification:

The species, habitat, and diet features do not have a natural order or hierarchy, and one-hot encoding allows us to treat each category as a separate feature. This is useful for predicting the behavior or characteristics of different animals.

Q7:

I would use a combination of nominal encoding and one-hot encoding to transform the categorical data into numerical data.

Step-by-step explanation:

1. Use nominal encoding to assign a unique integer value to each category of the "gender" feature. For example, assign 0 to "male" and 1 to "female".
2. Use one-hot encoding to transform the "contract type" feature into binary features. For example, create two new features "contract_type_1" and "contract_type_2" to represent the two categories of contract types.
3. Use one-hot encoding to transform the "age" feature into binary features. For example, create multiple new features "age_1", "age_2", etc. to represent the different age categories.

Justification:

The "gender" feature has a natural order or hierarchy, so nominal encoding is appropriate. The "contract type" and "age" features do not have a natural order or hierarchy, so one-hot encoding is appropriate.
