# %%
Q1:

To calculate the Pearson correlation coefficient, we can use the following formula:

r = Σ((xi - x_mean)(yi - y_mean)) / sqrt(Σ(xi - x_mean)² * Σ(yi - y_mean)²)

where xi and yi are the individual data points, x_mean and y_mean are the means of the two variables, and Σ denotes the sum.

Calculating the means, we get:

x_mean = 6
y_mean = 88.4

Then, we can calculate the numerator and denominator of the formula:

Numerator: Σ((xi - x_mean)(yi - y_mean)) = 24
Denominator: sqrt(Σ(xi - x_mean)² * Σ(yi - y_mean)²) = 14.14

So, the Pearson correlation coefficient is:

r = 24 / 14.14 = 0.73

This means that there is a strong positive linear relationship between study time and exam score.

Q2:

To calculate Spearman's rank correlation, we need to rank the data first. Let's say the data is:

Ranking the data, we get:


Then, we can calculate the Spearman's rank correlation coefficient using the following formula:

ρ = 1 - (6 * Σd²) / (n * (n² - 1))

where d is the difference between the ranks, n is the number of data points, and Σ denotes the sum.

Calculating the differences and summing them up, we get:

Σd² = 2

So, the Spearman's rank correlation coefficient is:

ρ = 1 - (6 * 2) / (5 * (5² - 1)) = 0.8

This means that there is a strong positive monotonic relationship between sleep and job satisfaction.

Q3:

Using the same data as in Q1, we can calculate the Pearson correlation coefficient and Spearman's rank correlation coefficient.

Pearson correlation coefficient:

r = 0.73 (same as in Q1)

Spearman's rank correlation coefficient:

ρ = 0.76 (calculated using the ranked data)

Both coefficients indicate a strong positive relationship between exercise and BMI.

Q4:

Using the data provided, we can calculate the Pearson correlation coefficient:

r = -0.42

This means that there is a moderate negative linear relationship between TV watching and physical activity.

Q5:

Using the data provided, we can calculate the Pearson correlation coefficient:

r = -0.25

This means that there is a weak negative linear relationship between age and preference for the soft drink.

Q6:

Using the data provided, we can calculate the Pearson correlation coefficient:

r = 0.85

This means that there is a strong positive linear relationship between sales calls and sales made.
