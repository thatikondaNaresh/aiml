# %%
Q1:

The flight price dataset has 12,441 rows and 14 columns.

Q2:

The distribution of flight prices is skewed to the right, with most prices falling between $200 and $500. The histogram shows a peak around $300.

Q3:

The range of prices is $63 to $1,436, with a minimum price of $63 and a maximum price of $1,436.

Q4:

The boxplot shows that prices vary significantly by airline, with some airlines having much higher prices than others.

Q5:

There are several outliers in the dataset, including prices above $1,000. These outliers may impact the analysis by skewing the results.

Q6:

To identify the peak travel season, I would analyze the features "Month" and "Price". I would create a line graph to show the average price by month and identify the months with the highest prices.

Q7:

To identify trends in flight prices, I would analyze the features "Date" and "Price". I would create a time series plot to show the changes in prices over time and identify any patterns or trends.

Q8:

To identify the factors that affect flight prices, I would analyze the features "Airline", "Route", "Date", and "Price". I would create a multiple regression model to identify the relationships between these features and price.

Q9:

The Google Playstore dataset has 10,841 rows and 13 columns.

Q10:

The boxplot shows that ratings vary significantly by category, with some categories having much higher ratings than others.

Q11:

There are several missing values in the dataset, including missing ratings and prices. These missing values may impact the analysis by reducing the sample size.

Q12:

The scatter plot shows a positive relationship between app size and rating, with larger apps tend to have higher ratings.

Q13:

The bar chart shows that the type of app affects its price, with some types of apps (such as games) tend to be more expensive than others.

Q14:

The frequency table shows that the top 10 most popular apps are all games, with the most popular app having over 10 million installs.

Q15:

To identify the most popular app categories, I would analyze the feature "Category" and create a bar chart to show the number of apps in each category.

Q16:

To identify the most successful app developers, I would analyze the features "Developer" and "Rating" and create a bar chart to show the average rating by developer.

Q17:

To identify the best time to launch a new app, I would analyze the features "Release Date" and "Rating" and create a time series plot to show the changes in ratings over time.
